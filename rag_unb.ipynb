# %% [markdown]
# ## Vectorstore

# %%
path = '/home/pedro/UnB/ChatBotUnB/'

# %%
docs_path = path + 'Base Tratada'
# perguntas_path = path_final + '/perguntas'
# resultados_path = path_final + '/resultados'

# %%
## colocar todos os txts em uma pasta e testar novamente

from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_chroma import Chroma
from langchain_community.document_loaders import WebBaseLoader, PyPDFLoader, DirectoryLoader
from langchain_ollama import OllamaEmbeddings
import os

# path = os.path.join(folder_path, path_base)
# print(path)

# Juntar o caminho completo dos arquivos e garantir que sejam arquivos válidos
# file_paths = [os.path.join(path_final, arquivo) for arquivo in os.listdir(docs_path) if os.path.isfile(os.path.join(docs_path, arquivo))]

# print("Caminhos dos arquivos encontrados:", file_paths)

loader = DirectoryLoader(docs_path,)
docs = loader.load()

# colocar referencias pesquisadas
text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size=100, chunk_overlap=50
)
doc_splits = text_splitter.split_documents(docs)

# Add to vectorDB
vectorstore = Chroma.from_documents(
    documents=doc_splits,
    collection_name="rag-unb",
    embedding=OllamaEmbeddings(model='nomic-embed-text'),
)
retriever = vectorstore.as_retriever()

# %% [markdown]
# ## Agents

# %%
# local_llm = 'llama3.2:1b'
# local_llm = 'llama3:8b-instruct-q4_0'
local_llm = 'phi3.5:3.8b-mini-instruct-q4_0'

# %%
### Retrieval Grader

from langchain_community.chat_models import ChatOllama
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.prompts import PromptTemplate

llm = ChatOllama(model=local_llm, format="json", temperature=0)

prompt = PromptTemplate(
    template="""<|begin_of_text|><|start_header_id|>system<|end_header_id|> Você é um aluno que avalia a relevância 
    de um documento recuperado para uma pergunta do usuário. Se o documento contiver palavras-chave relacionadas à pergunta do usuário, 
    classifique-o como relevante. Não precisa ser um teste rigoroso, o objetivo é filtrar recuperações errôneas. \n
    Dê uma pontuação binária de 'sim' ou 'não' para indicar se o documento é relevante para a questão. \n
    Forneça a pontuação binária como um JSON com uma única 'score' de chave e sem preâmbulo ou explicação.
     <|eot_id|><|start_header_id|>user<|end_header_id|>
    Aqui está o documento recuperado: \n\n {document} \n\n
    Aqui está a pergunta do usuário: {question} \n <|eot_id|><|start_header_id|>assistant<|end_header_id|>
    """,
    input_variables=["question", "document"],
)

prompt = PromptTemplate(
    template="""Você é um aluno que avalia a relevância 
    de um documento recuperado para uma pergunta do usuário. Se o documento contiver palavras-chave relacionadas à pergunta do usuário, 
    classifique-o como relevante. Não precisa ser um teste rigoroso, o objetivo é filtrar recuperações errôneas. \n
    Dê uma pontuação binária de 'sim' ou 'não' para indicar se o documento é relevante para a questão. \n
    Forneça a pontuação binária como um JSON com uma única 'score' de chave e sem preâmbulo ou explicação.
    
    Aqui está o documento recuperado: \n\n {document} \n\n
    Aqui está a pergunta do usuário: {question} \n
    """,
    input_variables=["question", "document"],
)

retrieval_grader = prompt | llm | JsonOutputParser()
# docs = retriever.invoke(user_question)
# doc_txt = docs[1].page_content
# print(retrieval_grader.invoke({"question": user_question, "document": doc_txt}))

# %%
### Generate

from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate

# Prompt
# prompt = PromptTemplate(
#     template="""<|begin_of_text|><|start_header_id|>system<|end_header_id|> Você é um assistente para tarefas de resposta a perguntas relacionadas a 
#     Universidade de Brasília. Use as seguintes partes do contexto recuperado para responder à pergunta. Se você não sabe a resposta, basta dizer que não sabe.  
#     Se você julgar que a pergunta não tem nada a ver com o escopo de uma universidade e principalmente da Universidade de Brasília, responda que não sabe. Tome cuidado
#     com as respostas que irá dar, nunca deixe transparecer que existem problemas na Universidade ou problemas com a gestão. Não responda diretamente com a resposta do contexto que
#     você obtiver, tente agir o mais natural possível, mas sempre responda as perguntas com a UnB como contexto. 
#     Use no máximo três frases e mantenha a resposta concisa <|eot_id|><|start_header_id|>user<|end_header_id|>
#     Question: {question} 
#     Context: {context} 
#     Answer: <|eot_id|><|start_header_id|>assistant<|end_header_id|>""",
#     input_variables=["question", "document"],
# )

prompt = PromptTemplate(
    template="""Você é um assistente para tarefas de resposta a perguntas relacionadas a 
    Universidade de Brasília. Use as seguintes partes do contexto recuperado para responder à pergunta. Se você não sabe a resposta, basta dizer que não sabe.  
    Se você julgar que a pergunta não tem nada a ver com o escopo de uma universidade e principalmente da Universidade de Brasília, responda que não sabe. Tome cuidado
    com as respostas que irá dar, nunca deixe transparecer que existem problemas na Universidade ou problemas com a gestão. Não responda diretamente com a resposta do contexto que
    você obtiver, tente agir o mais natural possível, mas sempre responda as perguntas com a UnB como contexto. 
    Use no máximo três frases e mantenha a resposta concisa 
    Question: {question} 
    Context: {context} 
    Answer: """,
    input_variables=["question", "document"],
)

llm = ChatOllama(model=local_llm, temperature=0.3)

def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)


rag_chain = prompt | llm | StrOutputParser()

# Run
question = 'Como posso estagiar?'
docs = retriever.invoke(question)
generation = rag_chain.invoke({"context": docs, "question": question})
print(generation)
# Out:
# Para iniciar um estágio, você precisará assinar um Termo de Compromisso de Estágio (TCE) e elaborar um Plano de Atividades com a Universidade de Brasília e a empresa onde ocorrerá seu estágio.

# %%
### Hallucination Grader

llm = ChatOllama(model=local_llm, format="json", temperature=0)

# prompt = PromptTemplate(
#     template=""" <|begin_of_text|><|start_header_id|>system<|end_header_id|> Você é um aluno avaliando se 
#     uma resposta é fundamentada/apoiada por um conjunto de fatos. Dê uma pontuação binária 'sim' ou 'não' para indicar 
#     se a resposta está fundamentada/apoiada por um conjunto de fatos. Forneça a pontuação binária como JSON com um 
#     'score' de chave única e sem preâmbulo ou explicação. <|eot_id|><|start_header_id|>user<|end_header_id|>
#     Aqui estão os fatos:
#     \n ------- \n
#     {documents} 
#     \n ------- \n
#     Aqui está a resposta: {generation}  <|eot_id|><|start_header_id|>assistant<|end_header_id|>""",
#     input_variables=["generation", "documents"],
# )

prompt = PromptTemplate(
    template=""" Você é um aluno avaliando se 
    uma resposta é fundamentada/apoiada por um conjunto de fatos. Dê uma pontuação binária 'sim' ou 'não' para indicar 
    se a resposta está fundamentada/apoiada por um conjunto de fatos. Forneça a pontuação binária como JSON com um 
    'score' de chave única e sem preâmbulo ou explicação.
    Aqui estão os fatos:
    \n ------- \n
    {documents} 
    \n ------- \n
    Aqui está a resposta: {generation}""",
    input_variables=["generation", "documents"],
)

hallucination_grader = prompt | llm | JsonOutputParser()
# hallucination_grader.invoke({"documents": docs, "generation": generation})

# %%
### Answer Grader

llm = ChatOllama(model=local_llm, format="json", temperature=0)

# prompt = PromptTemplate(
#     template="""<|begin_of_text|><|start_header_id|>system<|end_header_id|> Você é um avaliador avaliando se um 
#     resposta é útil para resolver uma questão. Dê uma pontuação binária 'sim' ou 'não' para indicar se a resposta é 
#     útil para resolver uma questão. Forneça a pontuação binária como um JSON com uma 'score' de chave e sem preâmbulo ou explicação.
#      <|eot_id|><|start_header_id|>user<|end_header_id|> Aqui está a resposta:
#     \n ------- \n
#     {generation} 
#     \n ------- \n
#     Aqui está a pergunta: {question} <|eot_id|><|start_header_id|>assistant<|end_header_id|>""",
#     input_variables=["generation", "question"],
# )

prompt = PromptTemplate(
    template="""Você é um avaliador avaliando se um 
    resposta é útil para resolver uma questão. Dê uma pontuação binária 'sim' ou 'não' para indicar se a resposta é 
    útil para resolver uma questão. Forneça a pontuação binária como um JSON com uma 'score' de chave e sem preâmbulo ou explicação.
    Aqui está a resposta:
    \n ------- \n
    {generation} 
    \n ------- \n
    Aqui está a pergunta: {question} """,
    input_variables=["generation", "question"],
)


answer_grader = prompt | llm | JsonOutputParser()
# answer_grader.invoke({"question": question, "generation": generation})

# %%
### Question Re-writer

llm = ChatOllama(model=local_llm, temperature=0)

re_write_prompt = PromptTemplate(
    template="""Você é um reescritor de perguntas que converte uma pergunta de entrada em uma versão melhor e otimizada \n 
     para recuperação de vectorstore sempre em português. Veja a inicial e formule uma pergunta melhorada. \n
     Aqui está a pergunta inicial: \n\n {question}. Pergunta melhorada sem preâmbulo: \n """,
    input_variables=["generation", "question"],
)

question_rewriter = re_write_prompt | llm | StrOutputParser()
# question_rewriter.invoke({"question": question})

# %% [markdown]
# ## Grafo

# %%
from typing import List

from typing_extensions import TypedDict


class GraphState(TypedDict):
    """
    Represents the state of our graph.

    Attributes:
        question: question
        generation: LLM generation
        documents: list of documents
    """

    question: str
    generation: str
    documents: List[str]

# %%
### Nodes


def retrieve(state):
    """
    Retrieve documents

    Args:
        state (dict): The current graph state

    Returns:
        state (dict): New key added to state, documents, that contains retrieved documents
    """
    question = state["question"]

    # Retrieval
    documents = retriever.get_relevant_documents(question)
    return {"documents": documents, "question": question}


def generate(state):
    """
    Generate answer

    Args:
        state (dict): The current graph state

    Returns:
        state (dict): New key added to state, generation, that contains LLM generation
    """
    question = state["question"]
    documents = state["documents"]

    # RAG generation
    generation = rag_chain.invoke({"context": documents, "question": question})
    return {"documents": documents, "question": question, "generation": generation}


def grade_documents(state):
    """
    Determines whether the retrieved documents are relevant to the question.

    Args:
        state (dict): The current graph state

    Returns:
        state (dict): Updates documents key with only filtered relevant documents
    """

    question = state["question"]
    documents = state["documents"]

    # Score each doc
    filtered_docs = []
    for d in documents:
        score = retrieval_grader.invoke(
            {"question": question, "document": d.page_content}
        )
        grade = score["score"]
        if grade == "sim":
            filtered_docs.append(d)
        else:
            continue
    return {"documents": filtered_docs, "question": question}


def transform_query(state):
    """
    Transform the query to produce a better question.

    Args:
        state (dict): The current graph state

    Returns:
        state (dict): Updates question key with a re-phrased question
    """

    question = state["question"]
    documents = state["documents"]

    # Re-write question
    better_question = question_rewriter.invoke({"question": question})
    return {"documents": documents, "question": better_question}


### Edges


def decide_to_generate(state):
    """
    Determines whether to generate an answer, or re-generate a question.

    Args:
        state (dict): The current graph state

    Returns:
        str: Binary decision for next node to call
    """
    state["question"]
    filtered_documents = state["documents"]

    if not filtered_documents:
        return "transform_query"
    else:
        return "generate"


def grade_generation_v_documents_and_question(state):
    """
    Determines whether the generation is grounded in the document and answers question.

    Args:
        state (dict): The current graph state

    Returns:
        str: Decision for next node to call
    """

    question = state["question"]
    documents = state["documents"]
    generation = state["generation"]

    score = hallucination_grader.invoke(
        {"documents": documents, "generation": generation}
    )
    grade = score["score"]

    # Check hallucination
    if grade == "sim":
        score = answer_grader.invoke({"question": question, "generation": generation})
        grade = score["score"]
        if grade == "sim":
            return "useful"
        else:
            return "not useful"
    else:
        return "not supported"

# %%
from langgraph.graph import END, StateGraph, START

workflow = StateGraph(GraphState)

# Define the nodes
workflow.add_node("retrieve", retrieve)  # retrieve
workflow.add_node("grade_documents", grade_documents)  # grade documents
workflow.add_node("generate", generate)  # generatae
workflow.add_node("transform_query", transform_query)  # transform_query


# Build graph
workflow.add_edge(START, "retrieve")
workflow.add_edge("retrieve", "grade_documents")
workflow.add_conditional_edges(
    "grade_documents",
    decide_to_generate,
    {
        "transform_query": "transform_query",
        "generate": "generate",
    },
)
workflow.add_edge("transform_query", "retrieve")
workflow.add_conditional_edges(
    "generate",
    grade_generation_v_documents_and_question,
    {
        "not supported": "generate",
        "useful": END,
        "not useful": "transform_query",
    },
)

# Compile
app = workflow.compile()

# %% [markdown]
# ## Inferência

# %%
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
def run(question):
    try:
        inputs = {"question": question}
        for output in app.stream(inputs):
            for key, value in output.items():
                pass
        return value["generation"]
    except:
        return f'Erro de inferência na pergunta: {question}'

# %%
def limpar_frase(frase):
    # Remove \xa0 (espaço não quebrável)
    try:
        frase = frase.replace('\xa0', '')
        
        # Remove numeração no início (como "1. " ou "a. ")
        frase = re.sub(r'^\d+\.\s*|^[a-z]+\.\s*', '', frase)
        
        # Remove espaços em branco extras no início e fim da frase
        frase = frase.strip()
    
        return frase
    except:
        return "Vazio"

# %%
def calculate_cosine_similarity(text1, text2):
    if text1 is np.nan:
        return 'text1 vazio'
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform([text1, text2])
    cosine_sim = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:2])
    return cosine_sim[0][0]

# %%
# Prompt
# prompt = PromptTemplate(
#     template="""<|begin_of_text|><|start_header_id|>system<|end_header_id|> Você é um assistente para tarefas de resposta a perguntas relacionadas a 
#     Universidade de Brasília. Compare as seguintes respostas dadas por um humano e a outra por um ChatBot. Se elas estiverem parecidas o suficiente e responderem a mesma coisa,
#     classifique a resposta como relevante. Dê uma pontuação binária de 'sim' ou 'não' para indicar se os textos são parecidos o suficiente. Seja rigoroso. Forneça a pontuação binária como um JSON com 
#     uma único 'score' de chave e sem preâmbulo ou explicação.
#      <|eot_id|><|start_header_id|>user<|end_header_id|>
    
#     Aqui está a resposta do humano: \n\n {human_response} \n\n
#     Aqui está a resposta do Chatbot: {chatbot_response} \n <|eot_id|><|start_header_id|>assistant<|end_header_id|>

#     Answer: <|eot_id|><|start_header_id|>assistant<|end_header_id|>""",
#     input_variables=["human_response", "chatbot_response"],
# )

prompt = PromptTemplate(
    template=""" Você é um assistente para tarefas de resposta a perguntas relacionadas a 
    Universidade de Brasília. Compare as seguintes respostas dadas por um humano e a outra por um ChatBot. Se elas estiverem parecidas o suficiente e responderem a mesma coisa,
    classifique a resposta como relevante. Dê uma pontuação binária de 'sim' ou 'não' para indicar se os textos são parecidos o suficiente. Seja rigoroso. Forneça a pontuação binária como um JSON com 
    uma único 'score' de chave e sem preâmbulo ou explicação.
    
    
    Aqui está a resposta do humano: \n\n {human_response} \n\n
    Aqui está a resposta do Chatbot: {chatbot_response} \n <|eot_id|><|start_header_id|>assistant<|end_header_id|>

    Answer: """,
    input_variables=["human_response", "chatbot_response"],
)

vote_llm = ChatOllama(model=local_llm, temperature=0.3)

# Chain
responses_grader = prompt | vote_llm | JsonOutputParser()


def get_opinion(human_response, chatbot_response):
    try:
        return (responses_grader.invoke({"human_response": human_response, "chatbot_response": chatbot_response}))
    except:
        return "Erro na inferência de opinião"

# %%
def processar_planilhas(file_path, limpar_frase, run, get_opinion):
    # Carrega todas as planilhas do arquivo Excel
    planilhas = pd.ExcelFile(file_path)
    nomes_planilhas = planilhas.sheet_names
    print(nomes_planilhas)

    # Dicionário para armazenar os DataFrames modificados
    planilhas_modificadas = {}

    count = 0
    # Itera sobre os nomes das planilhas
    for sheet_name in nomes_planilhas:
        try:
            print(sheet_name)
            # Carrega a planilha atual
            df = pd.read_excel(file_path, sheet_name=sheet_name)
            
            # Extrai a lista de perguntas e aplica a função 'limpar_frase'
            questions = df['Perguntas'].tolist()
            questions = [limpar_frase(frase) for frase in questions]

            # Itera sobre as perguntas e usa a função 'run' para obter as respostas
            responses = []
            for question in questions:
                response = run(question)
                responses.append(response)

            # Adiciona as respostas como uma nova coluna no DataFrame
            df['Respostas da LLM'] = responses

            # Preenche valores ausentes na coluna 'Resposta Esperada'
            df['Resposta Esperada'].fillna(method='ffill', inplace=True)

            # Aplica a função 'get_opinion' para obter a opinião
            df['Atende?'] = df.apply(lambda row: get_opinion(row['Resposta Esperada'], row['Respostas da LLM']), axis=1)
            
            # Armazena o DataFrame modificado
            planilhas_modificadas[sheet_name] = df

            print(f"Processamento concluído para a planilha: {sheet_name}")
        except:
            print(f'erro na sheet {sheet_name}')
            pass


    # Salva todas as planilhas modificadas no arquivo Excel
    with pd.ExcelWriter(file_path, engine='openpyxl', mode='w') as writer:
        for sheet_name, df in planilhas_modificadas.items():
            df.to_excel(writer, sheet_name=sheet_name, index=False)

# %%
processar_planilhas('/home/pedro/UnB/ChatBotUnB/Resultados das Perguntas (SAA).xlsx', limpar_frase, run, get_opinion)
# Out:
# ['Alteração de Estrutura Curricul', 'Aproveitamentos', 'Atividades', 'Cursos e Currículos', 'Desligamento e Reintegração', 'Histórico Escolar', 'Processo de Matrícula', 'Ingresso na UnB', 'Formatura', 'Trancamento', 'Configuração']
# Alteração de Estrutura Curricul
# /home/pedro/anaconda3/envs/chatbot/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /tmp/ipykernel_23611/3671624933.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Resposta Esperada'].fillna(method='ffill', inplace=True)
# /tmp/ipykernel_23611/3671624933.py:32: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Resposta Esperada'].fillna(method='ffill', inplace=True)
# Processamento concluído para a planilha: Alteração de Estrutura Curricul
# Aproveitamentos
# /tmp/ipykernel_23611/3671624933.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Resposta Esperada'].fillna(method='ffill', inplace=True)
# /tmp/ipykernel_23611/3671624933.py:32: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Resposta Esperada'].fillna(method='ffill', inplace=True)
# Processamento concluído para a planilha: Aproveitamentos
# Atividades
# /tmp/ipykernel_23611/3671624933.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Resposta Esperada'].fillna(method='ffill', inplace=True)
# /tmp/ipykernel_23611/3671624933.py:32: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Resposta Esperada'].fillna(method='ffill', inplace=True)
# Processamento concluído para a planilha: Atividades
# Cursos e Currículos
# /tmp/ipykernel_23611/3671624933.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Resposta Esperada'].fillna(method='ffill', inplace=True)
# /tmp/ipykernel_23611/3671624933.py:32: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Resposta Esperada'].fillna(method='ffill', inplace=True)
# Processamento concluído para a planilha: Cursos e Currículos
# Desligamento e Reintegração
# /tmp/ipykernel_23611/3671624933.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Resposta Esperada'].fillna(method='ffill', inplace=True)
# /tmp/ipykernel_23611/3671624933.py:32: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Resposta Esperada'].fillna(method='ffill', inplace=True)
# Processamento concluído para a planilha: Desligamento e Reintegração
# Histórico Escolar
# /tmp/ipykernel_23611/3671624933.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Resposta Esperada'].fillna(method='ffill', inplace=True)
# /tmp/ipykernel_23611/3671624933.py:32: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Resposta Esperada'].fillna(method='ffill', inplace=True)
# Processamento concluído para a planilha: Histórico Escolar
# Processo de Matrícula
# /home/pedro/anaconda3/envs/chatbot/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /tmp/ipykernel_23611/3671624933.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Resposta Esperada'].fillna(method='ffill', inplace=True)
# /tmp/ipykernel_23611/3671624933.py:32: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Resposta Esperada'].fillna(method='ffill', inplace=True)
# Processamento concluído para a planilha: Processo de Matrícula
# Ingresso na UnB
# /tmp/ipykernel_23611/3671624933.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Resposta Esperada'].fillna(method='ffill', inplace=True)
# /tmp/ipykernel_23611/3671624933.py:32: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Resposta Esperada'].fillna(method='ffill', inplace=True)
# Processamento concluído para a planilha: Ingresso na UnB
# Formatura
# /tmp/ipykernel_23611/3671624933.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Resposta Esperada'].fillna(method='ffill', inplace=True)
# /tmp/ipykernel_23611/3671624933.py:32: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Resposta Esperada'].fillna(method='ffill', inplace=True)
# Processamento concluído para a planilha: Formatura
# Trancamento
# /home/pedro/anaconda3/envs/chatbot/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /tmp/ipykernel_23611/3671624933.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Resposta Esperada'].fillna(method='ffill', inplace=True)
# /tmp/ipykernel_23611/3671624933.py:32: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Resposta Esperada'].fillna(method='ffill', inplace=True)
# Processamento concluído para a planilha: Trancamento
# Configuração
# erro na sheet Configuração

# %%
questions
# Out:
# ['Porque não tem vaga para todos os cursos no processo de mudança de curso?',
#  'Por que não existem vagas para todos os cursos na mudança de curso?',
#  'Qual é o motivo para não haver vagas em todos os cursos no processo de mudança de curso?',
#  'Por que nem todos os cursos oferecem vagas para mudança?',
#  'Qual a razão para a falta de vagas em alguns cursos no processo de mudança?',
#  'Por que é impossível encontrar vagas em todos os cursos para mudança?',
#  'E quanto à dupla diplomação, também é só para alguns cursos?',
#  'A dupla diplomação está disponível apenas para certos cursos?',
#  'A dupla diplomação é restrita a alguns cursos ou é mais abrangente?',
#  'A dupla diplomação é oferecida para todos os cursos ou apenas alguns?',
#  'Existe alguma limitação de cursos para dupla diplomação?',
#  'A dupla diplomação é específica para determinados cursos?',
#  'Quando será o ingresso dos selecionados?*******',
#  'Quando ocorrerá o ingresso dos selecionados?',
#  'Qual é a data prevista para o ingresso dos candidatos selecionados?',
#  'Em que momento será o ingresso dos selecionados?',
#  'Quando os selecionados começarão suas atividades?',
#  'Qual é a previsão para o ingresso dos estudantes selecionados?',
#  'A dupla diplomação só se aplica para outra as habilitações do mesmo curso?',
#  'A dupla diplomação se limita a outras habilitações do mesmo curso?',
#  'É possível obter dupla diplomação entre habilitações diferentes do mesmo curso?',
#  'A dupla diplomação é restrita a habilitações do mesmo curso?',
#  'A dupla diplomação permite diferentes habilitações no mesmo curso?',
#  'A dupla diplomação se aplica apenas a habilitações dentro do mesmo curso?',
#  'Preciso ter certificado de habilidade específica para solicitar dupla diplomação em Arquitetura ou Design Gráfico?',
#  'É necessário um certificado de habilidade específica para dupla diplomação em Arquitetura ou Design Gráfico?',
#  'Preciso de uma certificação específica para solicitar dupla diplomação em Arquitetura ou Design Gráfico?',
#  'É obrigatório possuir um certificado de habilidade específica para dupla diplomação em Arquitetura ou Design Gráfico?',
#  'Existe alguma exigência de certificado para dupla diplomação em Arquitetura ou Design Gráfico?',
#  'A dupla diplomação em Arquitetura ou Design Gráfico requer um certificado de habilidade específica?',
#  'Quanto à mudança de turno, vai ter edital para essa opção?',
#  'Haverá um edital para mudança de turno?',
#  'Existe um edital previsto para mudança de turno?',
#  'Vai ter um edital para os interessados em mudar de turno?',
#  'Está planejado um edital para mudança de turno?',
#  'Vai sair um edital para quem deseja mudar de turno?',
#  'E o Edital para segunda graduação e para transferência?',
#  'Quando será publicado o edital para segunda graduação e transferência?',
#  'Vai haver um edital para segunda graduação e transferência?',
#  'Existe um edital previsto para segunda graduação e transferência?',
#  'Quando podemos esperar o edital para segunda graduação e transferência?',
#  'O edital para segunda graduação e transferência será divulgado em breve?']

# %%
responses = []

# Itera sobre as perguntas e usa a função 'run' para obter as respostas
for question in questions:
    response = run(question)
    responses.append(response)

# Adiciona as respostas como uma nova coluna no DataFrame
df['Respostas da LLM'] = responses
# Out:
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='a. Estagiários têm seguro contra acidentes pessoais?
#
# b. O estagiário tem direito a seguro contra acidentes pessoais?
#
# c. O seguro contra acidentes pessoais é obrigatório para estagiários?' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio Supervisionado das Licenciaturas.docx'}
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='a. Estagiários têm seguro contra acidentes pessoais?
#
# b. O estagiário tem direito a seguro contra acidentes pessoais?
#
# c. O seguro contra acidentes pessoais é obrigatório para estagiários?' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio Supervisionado das Licenciaturas.docx'}
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='c. O seguro contra acidentes pessoais é obrigatório para estagiários?
#
# d. É necessário seguro contra acidentes pessoais para estágio?
#
# e. Estagiários recebem seguro contra acidentes pessoais?' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio Supervisionado das Licenciaturas.docx'}
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='c. O seguro contra acidentes pessoais é obrigatório para estagiários?
#
# d. É necessário seguro contra acidentes pessoais para estágio?
#
# e. Estagiários recebem seguro contra acidentes pessoais?' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio Supervisionado das Licenciaturas.docx'}
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='c. Como preencho as datas do estágio no TCE?
#
# d. Como devo preencher o período do estágio no TCE?
#
# e. Como preencho as informações sobre o período de estágio no Termo de Compromisso?' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio Supervisionado das Licenciaturas.docx'}
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='c. Como preencho as datas do estágio no TCE?
#
# d. Como devo preencher o período do estágio no TCE?
#
# e. Como preencho as informações sobre o período de estágio no Termo de Compromisso?' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio Supervisionado das Licenciaturas.docx'}
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='c. Quais são as condições em que o estágio deve ser remunerado?
#
# d. Em que casos o estágio precisa ser remunerado?' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio - Perguntas Gerais.docx'}
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='c. Quais são as condições em que o estágio deve ser remunerado?
#
# d. Em que casos o estágio precisa ser remunerado?' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio - Perguntas Gerais.docx'}
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='e. Quando o convênio começa a ser efetivo?
#
# O convênio ficará vigente após a assinatura do Representante Legal da Empresa nas minutas de Convênio e Plano de Trabalho. Após a assinatura o convênio terá vigência de 05(cinco) anos.' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio - Perguntas sobre Convênios.docx'}
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='e. Quando o convênio começa a ser efetivo?
#
# O convênio ficará vigente após a assinatura do Representante Legal da Empresa nas minutas de Convênio e Plano de Trabalho. Após a assinatura o convênio terá vigência de 05(cinco) anos.' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio - Perguntas sobre Convênios.docx'}
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='Os estudantes recém-ingressos são matriculados automaticamente pela universidade nos componentes curriculares do primeiro semestre de seus cursos. A matrícula em componentes que não permitem solicitação online, ou para recém-ingressos por transferência facultativa ou com diploma de nível superior, é responsabilidade das' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Matrículas/docs/resolucao_ceg_0003_2021_matricula_componentes_curriculares.txt'}
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='As matrículas não preenchidas durante essas etapas são disponibilizadas para matrícula direta, sem critérios de priorização, e são realizadas por ordem de solicitação. Estudantes recém-ingressos são matriculados automaticamente pela universidade nos componentes curriculares do primeiro semestre.' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Matrículas/docs/Resolucao_CEG_003_2021_Dispe_sobre_o_processo_de_matrcula_em_componentes_curri.txt'}
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='d. Estrangeiros matriculados em instituições brasileiras podem fazer estágios?
#
# e. Estudantes estrangeiros têm permissão para estagiar?' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio - Perguntas Gerais.docx'}
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION DOES NOT ADDRESS QUESTION---
# ---TRANSFORM QUERY---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='d. Quanto tempo um estágio pode durar na mesma concedente?
#
# e. Existe um limite para a duração do estágio na mesma concedente?
# Até dois anos, para o mesmo concedente, exceto quando se tratar de estagiário portador de deficiência.' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio - Perguntas Gerais.docx'}
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='d. Quanto tempo um estágio pode durar na mesma concedente?
#
# e. Existe um limite para a duração do estágio na mesma concedente?
# Até dois anos, para o mesmo concedente, exceto quando se tratar de estagiário portador de deficiência.' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio - Perguntas Gerais.docx'}
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='d. Quais são as diferentes formas de estágio?
#
# e. Quais são as categorias de estágio?
#
# Somente existem 02 (duas) modalidade: Estágio obrigatório e Estágio não obrigatório.' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio - Perguntas Gerais.docx'}
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='d. Quais são as diferentes formas de estágio?
#
# e. Quais são as categorias de estágio?
#
# Somente existem 02 (duas) modalidade: Estágio obrigatório e Estágio não obrigatório.' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio - Perguntas Gerais.docx'}
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: ALL DOCUMENTS ARE NOT RELEVANT TO QUESTION, TRANSFORM QUERY---
# ---TRANSFORM QUERY---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='d. Quanto tempo um estágio pode durar na mesma concedente?
#
# e. Existe um limite para a duração do estágio na mesma concedente?
# Até dois anos, para o mesmo concedente, exceto quando se tratar de estagiário portador de deficiência.' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio - Perguntas Gerais.docx'}
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='d. Quanto tempo um estágio pode durar na mesma concedente?
#
# e. Existe um limite para a duração do estágio na mesma concedente?
# Até dois anos, para o mesmo concedente, exceto quando se tratar de estagiário portador de deficiência.' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio - Perguntas Gerais.docx'}
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='d. Quais são as diferentes formas de estágio?
#
# e. Quais são as categorias de estágio?
#
# Somente existem 02 (duas) modalidade: Estágio obrigatório e Estágio não obrigatório.' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio - Perguntas Gerais.docx'}
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='d. Quais são as diferentes formas de estágio?
#
# e. Quais são as categorias de estágio?
#
# Somente existem 02 (duas) modalidade: Estágio obrigatório e Estágio não obrigatório.' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio - Perguntas Gerais.docx'}
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: ALL DOCUMENTS ARE NOT RELEVANT TO QUESTION, TRANSFORM QUERY---
# ---TRANSFORM QUERY---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='d. Quanto tempo um estágio pode durar na mesma concedente?
#
# e. Existe um limite para a duração do estágio na mesma concedente?
# Até dois anos, para o mesmo concedente, exceto quando se tratar de estagiário portador de deficiência.' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio - Perguntas Gerais.docx'}
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='d. Quanto tempo um estágio pode durar na mesma concedente?
#
# e. Existe um limite para a duração do estágio na mesma concedente?
# Até dois anos, para o mesmo concedente, exceto quando se tratar de estagiário portador de deficiência.' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio - Perguntas Gerais.docx'}
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='irá orientar os "estudantes" a encontrarem um local para realização de estágio e a preencher a documentação necessária; Preenchimento da documentação de estágio.' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio Supervisionado das Licenciaturas.docx'}
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='irá orientar os "estudantes" a encontrarem um local para realização de estágio e a preencher a documentação necessária; Preenchimento da documentação de estágio.' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio Supervisionado das Licenciaturas.docx'}
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: ALL DOCUMENTS ARE NOT RELEVANT TO QUESTION, TRANSFORM QUERY---
# ---TRANSFORM QUERY---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='1.11 Os estágios devem ser presenciais?
#
# a. Os estágios têm que ser presenciais ou podem ser remotos?
#
# b. Estágios precisam ser presenciais ou podem ser feitos remotamente?
#
# c. O estágio tem que ser feito de forma presencial?' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio Supervisionado das Licenciaturas.docx'}
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='1.11 Os estágios devem ser presenciais?
#
# a. Os estágios têm que ser presenciais ou podem ser remotos?
#
# b. Estágios precisam ser presenciais ou podem ser feitos remotamente?
#
# c. O estágio tem que ser feito de forma presencial?' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio Supervisionado das Licenciaturas.docx'}
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='Somente existem 02 (duas) modalidade: Estágio obrigatório e Estágio não obrigatório.
#
# 2. As atividades de extensão, de monitorias e de iniciação científica na educação superior desenvolvidas pelo estudante podem ser equiparadas ao estágio?' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio - Perguntas Gerais.docx'}
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='Somente existem 02 (duas) modalidade: Estágio obrigatório e Estágio não obrigatório.
#
# 2. As atividades de extensão, de monitorias e de iniciação científica na educação superior desenvolvidas pelo estudante podem ser equiparadas ao estágio?' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio - Perguntas Gerais.docx'}
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='d. Quais são as diferentes formas de estágio?
#
# e. Quais são as categorias de estágio?
#
# Somente existem 02 (duas) modalidade: Estágio obrigatório e Estágio não obrigatório.' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio - Perguntas Gerais.docx'}
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='d. Quais são as diferentes formas de estágio?
#
# e. Quais são as categorias de estágio?
#
# Somente existem 02 (duas) modalidade: Estágio obrigatório e Estágio não obrigatório.' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio - Perguntas Gerais.docx'}
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: ALL DOCUMENTS ARE NOT RELEVANT TO QUESTION, TRANSFORM QUERY---
# ---TRANSFORM QUERY---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='e. Quando um estágio é obrigado a oferecer remuneração ou bolsa?
# No caso do estágio não obrigatório é compulsória a concessão de bolsa ou outra forma de contraprestação que venha a ser acordada no Termo de Compromisso do Estágio.' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio - Perguntas Gerais.docx'}
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='e. Quando um estágio é obrigado a oferecer remuneração ou bolsa?
# No caso do estágio não obrigatório é compulsória a concessão de bolsa ou outra forma de contraprestação que venha a ser acordada no Termo de Compromisso do Estágio.' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio - Perguntas Gerais.docx'}
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='e. O estágio requer acompanhamento pelo professor orientador e pelo supervisor do estágio?' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio - Perguntas Gerais.docx'}
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='e. O estágio requer acompanhamento pelo professor orientador e pelo supervisor do estágio?' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio - Perguntas Gerais.docx'}
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='Por ser caracterizado como atividade de caráter pedagógico, o estagiário deverá preparar os relatórios acordados com o professor da UnB.
# Na parte legal, o estagiário deverá entregar o Relatório de Conclusão de estágio e postá-lo no SIGAA.' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio Supervisionado das Licenciaturas.docx'}
# ---GRADE: DOCUMENT NOT RELEVANT---
# {'score': 'não'}
# page_content='Por ser caracterizado como atividade de caráter pedagógico, o estagiário deverá preparar os relatórios acordados com o professor da UnB.
# Na parte legal, o estagiário deverá entregar o Relatório de Conclusão de estágio e postá-lo no SIGAA.' metadata={'source': '/home/pedro/UnB/ChatBotUnB/Bases/Estágios/docs/DEG Estágio Supervisionado das Licenciaturas.docx'}
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: ALL DOCUMENTS ARE NOT RELEVANT TO QUESTION, TRANSFORM QUERY---
# ---TRANSFORM QUERY---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---
# ---RETRIEVE---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS GROUNDED IN DOCUMENTS---
# ---GRADE GENERATION vs QUESTION---
# ---DECISION: GENERATION ADDRESSES QUESTION---

# %%
df['llms_cosine_similarity'] = df.apply(lambda row: calculate_cosine_similarity(row['Resp. Base Documentos'], row[f'Respostas da LLM']), axis=1)

# %%
df['Resposta Esperada'].fillna(method='ffill', inplace=True)
# Out:
# /tmp/ipykernel_10724/2234064586.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Resposta Esperada'].fillna(method='ffill', inplace=True)
# /tmp/ipykernel_10724/2234064586.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Resposta Esperada'].fillna(method='ffill', inplace=True)

# %%
df['base_cosine_similarity'] = df.apply(lambda row: calculate_cosine_similarity(row['Resposta Esperada'], row[f'Respostas da LLM']), axis=1)

# %%
df['Atende?'] = df.apply(lambda row: get_opinion(row['Resposta Esperada'], row[f'Respostas da LLM']), axis=1)

# %%
df
# Out:
#                                             Perguntas  \
# 0   1. Porque não tem vaga para todos os cursos no...
# 1   a. Por que não existem vagas para todos os cur...
# 2   b. Qual é o motivo para não haver vagas em tod...
# 3   c. Por que nem todos os cursos oferecem vagas ...
# 4   d. Qual a razão para a falta de vagas em algun...
# 5   e. Por que é impossível encontrar vagas em tod...
# 6   02. E quanto à dupla diplomação, também é só p...
# 7   a. A dupla diplomação está disponível apenas p...
# 8   b. A dupla diplomação é restrita a alguns curs...
# 9   c. A dupla diplomação é oferecida para todos o...
# 10  d. Existe alguma limitação de cursos para dupl...
# 11  e. A dupla diplomação é específica para determ...
# 12  03. Quando será o ingresso dos selecionados?**...
# 13   a. Quando ocorrerá o ingresso dos selecionados?
# 14  b. Qual é a data prevista para o ingresso dos ...
# 15  c. Em que momento será o ingresso dos selecion...
# 16  d. Quando os selecionados começarão suas ativi...
# 17  e. Qual é a previsão para o ingresso dos estud...
# 18  04. A dupla diplomação só se aplica para outra...
# 19  a. A dupla diplomação se limita a outras habil...
# 20  b. É possível obter dupla diplomação entre hab...
# 21  c. A dupla diplomação é restrita a habilitaçõe...
# 22  d. A dupla diplomação permite diferentes habil...
# 23  e. A dupla diplomação se aplica apenas a habil...
# 24  05. Preciso ter certificado de habilidade espe...
# 25  a. É necessário um certificado de habilidade e...
# 26  b. Preciso de uma certificação específica para...
# 27  c. É obrigatório possuir um certificado de hab...
# 28  d. Existe alguma exigência de certificado para...
# 29  e. A dupla diplomação em Arquitetura ou Design...
# 30  06. Quanto à mudança de turno, vai ter edital ...
# 31        a. Haverá um edital para mudança de turno?
# 32  b. Existe um edital previsto para mudança de t...
# 33  c. Vai ter um edital para os interessados em m...
# 34  d. Está planejado um edital para mudança de tu...
# 35  e. Vai sair um edital para quem deseja mudar d...
# 36  07.  E o Edital para segunda graduação e para ...
# 37  a. Quando será publicado o edital para segunda...
# 38  b. Vai haver um edital para segunda graduação ...
# 39  c. Existe um edital previsto para segunda grad...
# 40  d. Quando podemos esperar o edital para segund...
# 41  e. O edital para segunda graduação e transferê...
#
#                                     Resposta Esperada  \
# 0   A mudança de curso e a dupla diplomação fazem ...
# 1   A mudança de curso e a dupla diplomação fazem ...
# 2   A mudança de curso e a dupla diplomação fazem ...
# 3   A mudança de curso e a dupla diplomação fazem ...
# 4   A mudança de curso e a dupla diplomação fazem ...
# 5   A mudança de curso e a dupla diplomação fazem ...
# 6   As vagas de dupla diplomação seguem a mesma ló...
# 7   As vagas de dupla diplomação seguem a mesma ló...
# 8   As vagas de dupla diplomação seguem a mesma ló...
# 9   As vagas de dupla diplomação seguem a mesma ló...
# 10  As vagas de dupla diplomação seguem a mesma ló...
# 11  As vagas de dupla diplomação seguem a mesma ló...
# 12  Os classificados no edital aberto para inscriç...
# 13  Os classificados no edital aberto para inscriç...
# 14  Os classificados no edital aberto para inscriç...
# 15  Os classificados no edital aberto para inscriç...
# 16  Os classificados no edital aberto para inscriç...
# 17  Os classificados no edital aberto para inscriç...
# 18  Não, é possível se candidatar a dupla diplomaç...
# 19  Não, é possível se candidatar a dupla diplomaç...
# 20  Não, é possível se candidatar a dupla diplomaç...
# 21  Não, é possível se candidatar a dupla diplomaç...
# 22  Não, é possível se candidatar a dupla diplomaç...
# 23  Não, é possível se candidatar a dupla diplomaç...
# 24  Sim. Os cursos que exigem habilidade específic...
# 25  Sim. Os cursos que exigem habilidade específic...
# 26  Sim. Os cursos que exigem habilidade específic...
# 27  Sim. Os cursos que exigem habilidade específic...
# 28  Sim. Os cursos que exigem habilidade específic...
# 29  Sim. Os cursos que exigem habilidade específic...
# 30  Não existe mais edital de mudança de turno, po...
# 31  Não existe mais edital de mudança de turno, po...
# 32  Não existe mais edital de mudança de turno, po...
# 33  Não existe mais edital de mudança de turno, po...
# 34  Não existe mais edital de mudança de turno, po...
# 35  Não existe mais edital de mudança de turno, po...
# 36  Esses são os editais de PORTADOR DE DIPLOMA DE...
# 37  Esses são os editais de PORTADOR DE DIPLOMA DE...
# 38  Esses são os editais de PORTADOR DE DIPLOMA DE...
# 39  Esses são os editais de PORTADOR DE DIPLOMA DE...
# 40  Esses são os editais de PORTADOR DE DIPLOMA DE...
# 41  Esses são os editais de PORTADOR DE DIPLOMA DE...
#
#                                 Resp. Base Documentos  \
# 0   O processo de mudança de curso na UnB é limita...
# 1   A distribuição de vagas na mudança de curso é ...
# 2   O motivo para não haver vagas em todos os curs...
# 3   Nem todos os cursos oferecem vagas para mudanç...
# 4   A falta de vagas em alguns cursos no processo ...
# 5   A impossibilidade de encontrar vagas em todos ...
# 6   Sim, a dupla diplomação é uma forma de ingress...
# 7   Sim, a dupla diplomação está disponível como f...
# 8   A dupla diplomação na UnB é restrita a alguns ...
# 9   A dupla diplomação é oferecida para todos os c...
# 10  Sim, de acordo com a Resolução do Conselho de ...
# 11  Sim, a dupla diplomação é específica para dete...
# 12  O ingresso dos selecionados ocorrerá no períod...
# 13  O ingresso dos selecionados ocorrerá no períod...
# 14  A data prevista para o ingresso dos candidatos...
# 15  O ingresso dos selecionados ocorrerá no períod...
# 16  Não há informações específicas sobre o início ...
# 17  A previsão para o ingresso dos estudantes sele...
# 18  Não, a dupla diplomação também pode ser aplica...
# 19  Não, a dupla diplomação na UnB não se limita a...
# 20  Sim, é possível obter dupla diplomação entre h...
# 21                    Tente perguntar de outra forma.
# 22  Sim, a dupla diplomação permite que o estudant...
# 23  Não, a dupla diplomação não se aplica apenas a...
# 24  Sim, é necessário ter certificado de habilidad...
# 25  Sim, é necessário apresentar um certificado de...
# 26  Sim, é necessário obter uma certificação em pr...
# 27  Sim, é obrigatório possuir um certificado de h...
# 28  Sim, para a dupla diplomação em Arquitetura ou...
# 29  Sim, a dupla diplomação em Arquitetura ou Desi...
# 30  Não há informações no contexto sobre a existên...
# 31  Não há informações específicas sobre a existên...
# 32  Não há informações no contexto sobre a existên...
# 33  Sim, de acordo com a resolução do Conselho de ...
# 34  Não há informações no contexto sobre um edital...
# 35  Não há informações no contexto sobre a publica...
# 36  O contexto fornecido não menciona especificame...
# 37  Não há informações disponíveis no contexto sob...
# 38  Não há informações no contexto sobre a existên...
# 39  Não há informações no contexto sobre a existên...
# 40  Não há informações no contexto sobre a previsã...
# 41  Não há informações no contexto fornecido sobre...
#
#                                      Respostas da LLM  llms_cosine_similarity  \
# 0   A mudança de curso e a dupla diplomação fazem ...                0.257373
# 1   A razão para a falta de vagas em alguns cursos...                0.418204
# 2   A razão para não haver vagas em todos os curso...                0.500675
# 3   A razão para nem todos os cursos oferecerem va...                0.183495
# 4   A razão para a falta de vagas em alguns cursos...                0.326725
# 5   A razão para a falta de vagas em alguns cursos...                0.408372
# 6   A dupla diplomação é mais abrangente e não est...                0.230733
# 7   A dupla diplomação está disponível apenas para...                0.213143
# 8   A dupla diplomação não está restrita a alguns ...                0.270464
# 9   A dupla diplomação é oferecida para qualquer c...                0.374796
# 10  Sim, existem limitações de cursos para dupla d...                0.329228
# 11  Sim, a dupla diplomação é específica para dete...                0.644029
# 12  A data prevista para o ingresso dos candidatos...                0.219069
# 13  A data prevista para o ingresso dos candidatos...                0.089587
# 14  A data prevista para o ingresso dos candidatos...                0.487191
# 15  Em que momento será o ingresso dos selecionado...                0.182563
# 16  Os selecionados começarão suas atividades após...                0.199896
# 17  A previsão é que os estudantes selecionados in...                0.101091
# 18  A dupla diplomação só se aplica para outra as ...                0.118870
# 19  A dupla diplomação é restrita às habilidades d...                0.235602
# 20  Sim, é possível obter dupla diplomação entre h...                0.857761
# 21  A dupla diplomação não está restrita a habilit...                0.000000
# 22  Sim, a dupla diplomação permite diferentes hab...                0.218588
# 23  Não, a dupla diplomação se aplica para qualque...                0.205210
# 24  Sim, é necessário um certificado de habilidade...                0.795864
# 25  Sim, é necessário um certificado de habilidade...                0.729938
# 26  Sim, é necessário ter uma certificação específ...                0.508210
# 27  Sim, é obrigatório possuir um certificado de h...                0.786332
# 28  Sim, é obrigatório possuir um certificado de h...                0.412457
# 29  Sim, é necessário um certificado de habilidade...                0.772193
# 30  Não há mais edital de mudança de turno, pois t...                0.368549
# 31  Erro de inferência na pergunta: Haverá um edit...                0.465292
# 32  Erro de inferência na pergunta: Existe um edit...                0.488717
# 33                                       Sim, é isso!                0.067354
# 34  Sim, está planejado um edital para mudança de ...                0.356300
# 35  Erro de inferência na pergunta: Vai sair um ed...                0.349224
# 36  O edital para segunda graduação e transferênci...                0.291801
# 37  De acordo com as informações disponíveis, não ...                0.391177
# 38  Sim, vai haver um edital para segunda graduaçã...                0.372091
# 39  Sim, existe um edital previsto para segunda gr...                0.342363
# 40  O edital para segunda graduação e transferênci...                0.279792
# 41  Sim, o edital para segunda graduação e transfe...                0.271619
#
#     base_cosine_similarity           Atende?
# 0                 0.824285  {'score': 'sim'}
# 1                 0.576887  {'score': 'sim'}
# 2                 0.491841  {'score': 'sim'}
# 3                 0.381960  {'score': 'sim'}
# 4                 0.575774  {'score': 'sim'}
# 5                 0.477122  {'score': 'sim'}
# 6                 0.142452  {'score': 'sim'}
# 7                 0.137511  {'score': 'não'}
# 8                 0.117134  {'score': 'não'}
# 9                 0.162691  {'score': 'não'}
# 10                0.207695  {'score': 'sim'}
# 11                0.139764  {'score': 'não'}
# 12                0.091706  {'score': 'não'}
# 13                0.046321  {'score': 'não'}
# 14                0.033715  {'score': 'não'}
# 15                0.000000  {'score': 'sim'}
# 16                0.023501  {'score': 'não'}
# 17                0.352145  {'score': 'sim'}
# 18                0.253093  {'score': 'não'}
# 19                0.120130  {'score': 'não'}
# 20                0.137520  {'score': 'sim'}
# 21                0.848987  {'score': 'sim'}
# 22                0.111856  {'score': 'sim'}
# 23                0.890706  {'score': 'sim'}
# 24                0.169242  {'score': 'sim'}
# 25                0.169242  {'score': 'sim'}
# 26                0.063730  {'score': 'sim'}
# 27                0.169242  {'score': 'sim'}
# 28                0.169242  {'score': 'sim'}
# 29                0.169242  {'score': 'sim'}
# 30                0.948126  {'score': 'sim'}
# 31                0.342257  {'score': 'não'}
# 32                0.359891  {'score': 'não'}
# 33                0.000000  {'score': 'sim'}
# 34                0.333581  {'score': 'não'}
# 35                0.274179  {'score': 'não'}
# 36                0.065956  {'score': 'não'}
# 37                0.199076  {'score': 'não'}
# 38                0.065956  {'score': 'sim'}
# 39                0.065956  {'score': 'sim'}
# 40                0.065956  {'score': 'não'}
# 41                0.061964  {'score': 'não'}

# %%
f"{resultados_path}/resultados_{local_llm}.xlsx"
# Out:
# '/home/pedro/UnB/ChatBotUnB/Bases/Mudança de curso, habilitação ou currículo, dupla habilitação e Dupla Diplomação/resultados/resultados_llama3:8b-instruct-q4_0.xlsx'

# %%
df.to_excel(f"{resultados_path}/resultados_{local_llm}.xlsx", index=False)
